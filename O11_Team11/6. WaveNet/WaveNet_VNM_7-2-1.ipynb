# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Đọc file CSV
file_path = 'VNM_Historical_Data.csv'  # Đường dẫn đến file CSV của bạn
data = pd.read_csv(file_path)

# Chuyển đổi cột 'Date' thành datetime và sắp xếp dữ liệu
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%y')
data.sort_values('Date', inplace=True)

data
# Out:
#            Date     Close      Open      High       Low     Vol.  Change %
# 0    2017-01-03  100082.0   99213.0  100319.0   99213.0   782840      0.88
# 1    2017-01-04  100240.0  100714.0  100793.0  100161.0   791240      0.16
# 2    2017-01-05  100082.0  100398.0  100398.0   99687.0   986830     -0.16
# 3    2017-01-06   99529.0  100082.0  100793.0   99529.0  1650000     -0.55
# 4    2017-01-09   99529.0  100082.0  100161.0   99529.0  1090000      0.00
# ...         ...       ...       ...       ...       ...      ...       ...
# 1736 2023-12-14   68400.0   68400.0   68900.0   68200.0  1460000      0.29
# 1737 2023-12-15   68100.0   68500.0   68600.0   68100.0  3740000     -0.44
# 1738 2023-12-18   67000.0   68100.0   68200.0   67000.0  3510000     -1.62
# 1739 2023-12-19   67000.0   67100.0   67400.0   66300.0  3060000      0.00
# 1740 2023-12-20   68100.0   67000.0   68200.0   67000.0  2600000      1.64
#
# [1741 rows x 7 columns]

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.title('Stock Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.7)
test_size = int(len(scaled_target) * 0.2)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.5)
test_size = int(len(scaled_target) * 0.3)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
def create_dataset(dataset, time_step):
    X, Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step)]
        X.append(a)
        Y.append(dataset[i + time_step])
    return np.array(X), np.array(Y)

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_validate, y_validate = create_dataset(validate_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_validate = X_validate.reshape(X_validate.shape[0], X_validate.shape[1], 1)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(100, 1)))
model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 25/25 [==============================] - 4s 41ms/step - loss: 0.0418 - val_loss: 0.0021
# Epoch 2/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0011
# Epoch 3/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 4/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 7.1389e-04
# Epoch 5/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 6/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 7/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 8/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 8.0470e-04
# Epoch 9/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 10/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 11/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 9.9219e-04
# Epoch 12/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 8.8946e-04
# Epoch 13/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 14/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 15/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 9.1882e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 17/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 18/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 19/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 20/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 9.6310e-04
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 7.6514e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 23/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0013 - val_loss: 9.4630e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 25/100
# 25/25 [==============================] - 0s 16ms/step - loss: 8.2387e-04 - val_loss: 6.5047e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 15ms/step - loss: 8.7973e-04 - val_loss: 8.3961e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 15ms/step - loss: 8.4929e-04 - val_loss: 8.7598e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 16ms/step - loss: 7.7484e-04 - val_loss: 6.6959e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.7835e-04 - val_loss: 7.7640e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 18ms/step - loss: 7.1792e-04 - val_loss: 0.0011
# Epoch 31/100
# 25/25 [==============================] - 0s 19ms/step - loss: 7.4745e-04 - val_loss: 0.0015
# Epoch 32/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 33/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.0510e-04 - val_loss: 8.0897e-04
# Epoch 34/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.6174e-04 - val_loss: 0.0018
# Epoch 35/100
# 25/25 [==============================] - 0s 16ms/step - loss: 7.2657e-04 - val_loss: 8.9139e-04
# Epoch 36/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.4526e-04 - val_loss: 0.0010
# Epoch 37/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.6607e-04 - val_loss: 0.0012
# Epoch 38/100
# 25/25 [==============================] - 1s 23ms/step - loss: 9.5110e-04 - val_loss: 0.0015
# Epoch 39/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.0495e-04 - val_loss: 9.5959e-04
# Epoch 40/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.9839e-04 - val_loss: 7.9929e-04
# Epoch 41/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.0666e-04 - val_loss: 6.7432e-04
# Epoch 42/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0016 - val_loss: 6.4237e-04
# Epoch 43/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 9.7949e-04
# Epoch 44/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.8139e-04 - val_loss: 9.0857e-04
# Epoch 45/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.7926e-04 - val_loss: 5.9728e-04
# Epoch 46/100
# 25/25 [==============================] - 0s 18ms/step - loss: 7.6368e-04 - val_loss: 7.5046e-04
# Epoch 47/100
# 25/25 [==============================] - 0s 19ms/step - loss: 5.3589e-04 - val_loss: 7.5394e-04
# Epoch 48/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.2489e-04 - val_loss: 5.6173e-04
# Epoch 49/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.1852e-04 - val_loss: 6.2789e-04
# Epoch 50/100
# 25/25 [==============================] - 0s 19ms/step - loss: 6.2522e-04 - val_loss: 5.9465e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8722e-04 - val_loss: 6.3522e-04
# Epoch 52/100
# 25/25 [==============================] - 0s 19ms/step - loss: 4.3870e-04 - val_loss: 7.6102e-04
# Epoch 53/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.9751e-04 - val_loss: 6.3455e-04
# Epoch 54/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.0497e-04 - val_loss: 7.3216e-04
# Epoch 55/100
# 25/25 [==============================] - 0s 15ms/step - loss: 5.8456e-04 - val_loss: 6.2461e-04
# Epoch 56/100
# 25/25 [==============================] - 0s 18ms/step - loss: 5.3051e-04 - val_loss: 7.9115e-04
# Epoch 57/100
# 25/25 [==============================] - 0s 17ms/step - loss: 7.9355e-04 - val_loss: 6.9282e-04
# Epoch 58/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.4811e-04 - val_loss: 6.2274e-04
# Epoch 59/100
# 25/25 [==============================] - 0s 19ms/step - loss: 6.5937e-04 - val_loss: 8.1130e-04
# Epoch 60/100
# 25/25 [==============================] - 0s 18ms/step - loss: 8.7613e-04 - val_loss: 6.8915e-04
# Epoch 61/100
# 25/25 [==============================] - 1s 22ms/step - loss: 6.6628e-04 - val_loss: 7.0824e-04
# Epoch 62/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.2766e-04 - val_loss: 6.3400e-04
# Epoch 63/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3572e-04 - val_loss: 6.2993e-04
# Epoch 64/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.8737e-04 - val_loss: 6.6176e-04
# Epoch 65/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.1417e-04 - val_loss: 7.2947e-04
# Epoch 66/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.2625e-04 - val_loss: 0.0010
# Epoch 67/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.9034e-04 - val_loss: 6.4472e-04
# Epoch 68/100
# 25/25 [==============================] - 0s 20ms/step - loss: 4.4997e-04 - val_loss: 7.5215e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.0017e-04 - val_loss: 6.6335e-04
# Epoch 70/100
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4855e-04 - val_loss: 6.9049e-04
# Epoch 71/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.6945e-04 - val_loss: 7.0212e-04
# Epoch 72/100
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4299e-04 - val_loss: 7.5165e-04
# Epoch 73/100
# 25/25 [==============================] - 0s 11ms/step - loss: 5.4538e-04 - val_loss: 7.2639e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.6351e-04 - val_loss: 8.3043e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.0025e-04 - val_loss: 7.1332e-04
# Epoch 76/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.9627e-04 - val_loss: 7.2639e-04
# Epoch 77/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.4924e-04 - val_loss: 7.4463e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 11ms/step - loss: 5.0886e-04 - val_loss: 9.8075e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 9.2125e-04
# Epoch 80/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.4519e-04 - val_loss: 8.1607e-04
# Epoch 81/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.3869e-04 - val_loss: 8.5278e-04
# Epoch 82/100
# 25/25 [==============================] - 0s 13ms/step - loss: 6.5723e-04 - val_loss: 7.1179e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.8896e-04 - val_loss: 8.9387e-04
# Epoch 84/100
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8665e-04 - val_loss: 8.8168e-04
# Epoch 85/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.3177e-04 - val_loss: 9.0448e-04
# Epoch 86/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.0216e-04 - val_loss: 0.0011
# Epoch 87/100
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9511e-04 - val_loss: 8.4216e-04
# Epoch 88/100
# 25/25 [==============================] - 0s 11ms/step - loss: 3.7829e-04 - val_loss: 9.6153e-04
# Epoch 89/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.3795e-04 - val_loss: 7.8934e-04
# Epoch 90/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.4409e-04 - val_loss: 8.3265e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.7768e-04 - val_loss: 8.0848e-04
# Epoch 92/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.9184e-04 - val_loss: 7.8805e-04
# Epoch 93/100
# 25/25 [==============================] - 0s 11ms/step - loss: 6.6210e-04 - val_loss: 9.7190e-04
# Epoch 94/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.6590e-04 - val_loss: 8.5308e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 13ms/step - loss: 3.9489e-04 - val_loss: 7.9131e-04
# Epoch 96/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.6191e-04 - val_loss: 0.0011
# Epoch 97/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.2531e-04 - val_loss: 7.7456e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 11ms/step - loss: 8.5343e-04 - val_loss: 0.0011
# Epoch 99/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.6830e-04 - val_loss: 6.9356e-04
# Epoch 100/100
# 25/25 [==============================] - 0s 10ms/step - loss: 3.9357e-04 - val_loss: 8.0977e-04

# %%
# Dự đoán trên tập test
test_predictions = model.predict(X_test)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
test_predictions_inverse = scaler.inverse_transform(test_predictions)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_test = mean_absolute_error(y_test_inverse, test_predictions_inverse)
rmse_test = np.sqrt(mean_squared_error(y_test_inverse, test_predictions_inverse))
mape_test = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

# In kết quả
print(f'Test MAE: {mae_test}, Test RMSE: {rmse_test}, Test MAPE: {mape_test}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_test_inverse, label='Thực tế')
plt.plot(test_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Test Giá Cổ Phiếu')
plt.xlabel('Date')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 2ms/step
# Test MAE: 1268.2757119455646, Test RMSE: 1615.580265298537, Test MAPE: 1.4288107519431512%

# %%
# Dự đoán trên tập validate
validate_predictions = model.predict(X_validate)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
validate_predictions_inverse = scaler.inverse_transform(validate_predictions)
y_validate_inverse = scaler.inverse_transform(y_validate.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_validate = mean_absolute_error(y_validate_inverse, validate_predictions_inverse)
rmse_validate = np.sqrt(mean_squared_error(y_validate_inverse, validate_predictions_inverse))
mape_validate = np.mean(np.abs((y_validate_inverse - validate_predictions_inverse) / y_validate_inverse)) * 100

# In kết quả
print(f'Validate MAE: {mae_validate}, Validate RMSE: {rmse_validate}, Validate MAPE: {mape_validate}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_validate_inverse, label='Thực tế')
plt.plot(validate_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Validate Giá Cổ Phiếu VNM')
plt.xlabel('Thời gian')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 14/14 [==============================] - 0s 4ms/step
# Validate MAE: 2574.877319625891, Validate RMSE: 3253.079414754367, Validate MAPE: 3.6276444490873616%

# %%
# Chuẩn bị dữ liệu đầu vào cho việc dự đoán
last_data = scaled_target[-100:]  # Lấy 100 điểm dữ liệu cuối cùng
current_batch = last_data.reshape((1, 100, 1))

# Dự đoán cho 30 ngày tiếp theo
for i in range(30):
    # Dự đoán cho ngày tiếp theo
    pred_next = model.predict(current_batch)[0]
    # Cập nhật dữ liệu đầu vào
    current_batch = np.append(current_batch[:,1:,:], [[pred_next]], axis=1)

# Chuyển đổi kết quả dự đoán về dạng ban đầu
future_predictions = scaler.inverse_transform(current_batch.reshape(-1, 1))

# In kết quả dự đoán
print(future_predictions[30:])  # In ra 30 giá trị dự đoán mới nhất
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# [[67000.        ]
#  [68000.        ]
#  [67600.        ]
#  [68000.        ]
#  [70400.        ]
#  [70900.        ]
#  [70000.        ]
#  [71000.        ]
#  [70800.        ]
#  [71400.        ]
#  [70700.        ]
#  [69600.        ]
#  [68700.        ]
#  [68900.        ]
#  [70700.        ]
#  [70300.        ]
#  [70000.        ]
#  [69300.        ]
#  [69500.        ]
#  [69400.        ]
#  [68700.        ]
#  [68300.        ]
#  [68100.        ]
#  [68500.        ]
#  [68400.        ]
#  [67400.        ]
#  [68400.        ]
#  [68800.        ]
#  [68100.        ]
#  [68500.        ]
#  [68400.        ]
#  [69000.        ]
#  [70000.        ]
#  [69400.        ]
#  [68200.        ]
#  [68400.        ]
#  [68100.        ]
#  [67000.        ]
#  [67000.        ]
#  [68100.        ]
#  [72163.37088543]
#  [75458.68059078]
#  [77488.66170212]
#  [78169.38513113]
#  [78119.29290833]
#  [77180.46149093]
#  [76305.53402667]
#  [75104.3052848 ]
#  [73914.5076747 ]
#  [72882.4964781 ]
#  [72143.89256394]
#  [71851.09512357]
#  [72135.94076853]
#  [72247.44476866]
#  [72488.71225801]
#  [72814.26741601]
#  [72786.57752002]
#  [72906.90549193]
#  [72790.09773965]
#  [72607.64934711]
#  [72525.21931191]
#  [72431.15628379]
#  [72246.56918536]
#  [72375.93661793]
#  [72302.03074388]
#  [72077.57905325]
#  [71922.45516252]
#  [71582.38388955]
#  [71674.23751779]
#  [71802.58116522]]

# %%
plt.figure(figsize=(14, 7))
plt.plot(future_predictions[30:])
plt.title('Next30days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
