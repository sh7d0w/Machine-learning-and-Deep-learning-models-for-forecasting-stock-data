# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
# Đọc file CSV
file_path = 'VCB_Historical_Data.csv'  # Đường dẫn đến file CSV của bạn
data = pd.read_csv(file_path)

# Chuyển đổi cột 'Date' thành datetime và sắp xếp dữ liệu
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%y')
data.sort_values('Date', inplace=True)

data
# Out:
#            Date  Close   Open   High    Low     Vol. Change %
# 0    2017-01-03  27643  26418  27828  26418  2580000    5.08%
# 1    2017-01-04  27457  27828  27903  27309  1710000   -0.67%
# 2    2017-01-05  27569  27383  27680  27346  1090000    0.41%
# 3    2017-01-06  28125  27606  28496  27531  3180000    2.02%
# 4    2017-01-09  28719  28348  28904  28274  3040000    2.11%
# ...         ...    ...    ...    ...    ...      ...      ...
# 1736 2023-12-14  84400  84000  84500  84000   840600    0.84%
# 1737 2023-12-15  82200  84000  84400  82200  2530000   -2.61%
# 1738 2023-12-18  81500  82800  82900  81500  1800000   -0.85%
# 1739 2023-12-19  81200  81500  81500  80100  1960000   -0.37%
# 1740 2023-12-20  81100  81200  81300  80500  1870000   -0.12%
#
# [1741 rows x 7 columns]

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.title('Stock Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.5)
test_size = int(len(scaled_target) * 0.3)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.5)
test_size = int(len(scaled_target) * 0.3)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
def create_dataset(dataset, time_step):
    X, Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step)]
        X.append(a)
        Y.append(dataset[i + time_step])
    return np.array(X), np.array(Y)

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_validate, y_validate = create_dataset(validate_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_validate = X_validate.reshape(X_validate.shape[0], X_validate.shape[1], 1)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(100, 1)))
model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 2s 22ms/step - loss: 0.0130 - val_loss: 0.0121
# Epoch 2/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 3/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 4/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 5/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0063
# Epoch 6/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 7/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0073
# Epoch 8/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 9/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0059
# Epoch 10/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 11/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 12/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.8810e-04 - val_loss: 0.0015
# Epoch 13/100
# 25/25 [==============================] - 0s 9ms/step - loss: 7.3477e-04 - val_loss: 0.0014
# Epoch 14/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.6008e-04 - val_loss: 0.0020
# Epoch 15/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.5729e-04 - val_loss: 0.0013
# Epoch 16/100
# 25/25 [==============================] - 0s 8ms/step - loss: 5.9812e-04 - val_loss: 0.0014
# Epoch 17/100
# 25/25 [==============================] - 0s 9ms/step - loss: 7.3797e-04 - val_loss: 0.0014
# Epoch 18/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.6872e-04 - val_loss: 0.0026
# Epoch 19/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.4869e-04 - val_loss: 0.0023
# Epoch 20/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.0897e-04 - val_loss: 0.0271
# Epoch 21/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0134
# Epoch 22/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.6020e-04 - val_loss: 0.0021
# Epoch 24/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.2504e-04 - val_loss: 0.0027
# Epoch 25/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0010 - val_loss: 0.0046
# Epoch 26/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.9420e-04 - val_loss: 0.0029
# Epoch 27/100
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2603e-04 - val_loss: 0.0032
# Epoch 28/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.3861e-04 - val_loss: 0.0014
# Epoch 29/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4
100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 68/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.5138e-04 - val_loss: 8.2490e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 19ms/step - loss: 1.9051e-04 - val_loss: 0.0014
# Epoch 70/100
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9408e-04 - val_loss: 0.0018
# Epoch 71/100
# 25/25 [==============================] - 0s 16ms/step - loss: 1.8988e-04 - val_loss: 7.9862e-04
# Epoch 72/100
# 25/25 [==============================] - 0s 16ms/step - loss: 1.8658e-04 - val_loss: 0.0010
# Epoch 73/100
# 25/25 [==============================] - 0s 16ms/step - loss: 1.9539e-04 - val_loss: 6.2500e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 16ms/step - loss: 1.8343e-04 - val_loss: 6.4861e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 16ms/step - loss: 2.0856e-04 - val_loss: 0.0010
# Epoch 76/100
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2080e-04 - val_loss: 0.0019
# Epoch 77/100
# 25/25 [==============================] - 0s 16ms/step - loss: 1.6645e-04 - val_loss: 0.0040
# Epoch 78/100
# 25/25 [==============================] - 0s 17ms/step - loss: 3.6089e-04 - val_loss: 0.0018
# Epoch 79/100
# 25/25 [==============================] - 0s 16ms/step - loss: 2.7246e-04 - val_loss: 7.0459e-04
# Epoch 80/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7797e-04 - val_loss: 0.0057
# Epoch 81/100
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7118e-04 - val_loss: 0.0038
# Epoch 82/100
# 25/25 [==============================] - 0s 16ms/step - loss: 3.3925e-04 - val_loss: 7.1348e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 18ms/step - loss: 2.4181e-04 - val_loss: 7.2706e-04
# Epoch 84/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7701e-04 - val_loss: 0.0011
# Epoch 85/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8860e-04 - val_loss: 0.0012
# Epoch 86/100
# 25/25 [==============================] - 1s 37ms/step - loss: 2.1237e-04 - val_loss: 0.0023
# Epoch 87/100
# 25/25 [==============================] - 1s 24ms/step - loss: 3.5728e-04 - val_loss: 0.0021
# Epoch 88/100
# 25/25 [==============================] - 1s 23ms/step - loss: 2.3747e-04 - val_loss: 6.4746e-04
# Epoch 89/100
# 25/25 [==============================] - 1s 24ms/step - loss: 1.4994e-04 - val_loss: 7.2686e-04
# Epoch 90/100
# 25/25 [==============================] - 1s 26ms/step - loss: 1.7837e-04 - val_loss: 0.0015
# Epoch 91/100
# 25/25 [==============================] - 1s 25ms/step - loss: 1.7866e-04 - val_loss: 0.0026
# Epoch 92/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.8653e-04 - val_loss: 0.0018
# Epoch 93/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.9076e-04 - val_loss: 0.0018
# Epoch 94/100
# 25/25 [==============================] - 1s 25ms/step - loss: 1.6125e-04 - val_loss: 0.0017
# Epoch 95/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7065e-04 - val_loss: 9.4250e-04
# Epoch 96/100
# 25/25 [==============================] - 1s 22ms/step - loss: 2.3232e-04 - val_loss: 0.0027
# Epoch 97/100
# 25/25 [==============================] - 1s 25ms/step - loss: 1.8576e-04 - val_loss: 0.0012
# Epoch 98/100
# 25/25 [==============================] - 1s 23ms/step - loss: 1.4070e-04 - val_loss: 0.0024
# Epoch 99/100
# 25/25 [==============================] - 1s 22ms/step - loss: 2.5715e-04 - val_loss: 6.6073e-04
# Epoch 100/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.4967e-04 - val_loss: 0.0031

# %%
# Dự đoán trên tập test
test_predictions = model.predict(X_test)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
test_predictions_inverse = scaler.inverse_transform(test_predictions)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_test = mean_absolute_error(y_test_inverse, test_predictions_inverse)
rmse_test = np.sqrt(mean_squared_error(y_test_inverse, test_predictions_inverse))
mape_test = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

# In kết quả
print(f'Test MAE: {mae_test}, Test RMSE: {rmse_test}, Test MAPE: {mape_test}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_test_inverse, label='Thực tế')
plt.plot(test_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Test Giá Cổ Phiếu')
plt.xlabel('Date')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 1s 7ms/step
# Test MAE: 3284.4396736391127, Test RMSE: 3694.8470922136953, Test MAPE: 4.274634001509424%

# %%
# Dự đoán trên tập validate
validate_predictions = model.predict(X_validate)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
validate_predictions_inverse = scaler.inverse_transform(validate_predictions)
y_validate_inverse = scaler.inverse_transform(y_validate.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_validate = mean_absolute_error(y_validate_inverse, validate_predictions_inverse)
rmse_validate = np.sqrt(mean_squared_error(y_validate_inverse, validate_predictions_inverse))
mape_validate = np.mean(np.abs((y_validate_inverse - validate_predictions_inverse) / y_validate_inverse)) * 100

# In kết quả
print(f'Validate MAE: {mae_validate}, Validate RMSE: {rmse_validate}, Validate MAPE: {mape_validate}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_validate_inverse, label='Thực tế')
plt.plot(validate_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Validate Giá Cổ Phiếu VNM')
plt.xlabel('Thời gian')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 14/14 [==============================] - 0s 6ms/step
# Validate MAE: 4066.777223129454, Validate RMSE: 4463.065339319214, Validate MAPE: 4.806780582889905%

# %%
# Chuẩn bị dữ liệu đầu vào cho việc dự đoán
last_data = scaled_target[-100:]  # Lấy 100 điểm dữ liệu cuối cùng
current_batch = last_data.reshape((1, 100, 1))

# Dự đoán cho 30 ngày tiếp theo
for i in range(30):
    # Dự đoán cho ngày tiếp theo
    pred_next = model.predict(current_batch)[0]
    # Cập nhật dữ liệu đầu vào
    current_batch = np.append(current_batch[:,1:,:], [[pred_next]], axis=1)

# Chuyển đổi kết quả dự đoán về dạng ban đầu
future_predictions = scaler.inverse_transform(current_batch.reshape(-1, 1))

# In kết quả dự đoán
print(future_predictions[30:])  # In ra 30 giá trị dự đoán mới nhất
# Out:
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 85ms/step
# [[84500.        ]
#  [85000.        ]
#  [85900.        ]
#  [86800.        ]
#  [87800.        ]
#  [89000.        ]
#  [88900.        ]
#  [89500.        ]
#  [88300.        ]
#  [89500.        ]
#  [87900.        ]
#  [86000.        ]
#  [85500.        ]
#  [86000.        ]
#  [87700.        ]
#  [88000.        ]
#  [85600.        ]
#  [86100.        ]
#  [86600.        ]
#  [86700.        ]
#  [85500.        ]
#  [86000.        ]
#  [85800.        ]
#  [85800.        ]
#  [85100.        ]
#  [84700.        ]
#  [85000.        ]
#  [86000.        ]
#  [85400.        ]
#  [85900.        ]
#  [85200.        ]
#  [85000.        ]
#  [84200.        ]
#  [84200.        ]
#  [83700.        ]
#  [84400.        ]
#  [82200.        ]
#  [81500.        ]
#  [81200.        ]
#  [81100.        ]
#  [76681.81461465]
#  [73615.64424825]
#  [70328.86495829]
#  [67003.87959993]
#  [63754.3475017 ]
#  [60234.94328982]
#  [56571.40717757]
#  [52831.16814137]
#  [50117.46065176]
#  [47923.69021773]
#  [46382.33802766]
#  [44870.89245591]
#  [43628.77827787]
#  [42445.79362619]
#  [41812.0326229 ]
#  [41683.03607407]
#  [41774.6075944 ]
#  [42118.227898  ]
#  [42414.06057611]
#  [42595.05755946]
#  [43265.32076257]
#  [43802.66899979]
#  [44632.43376678]
#  [45421.67217609]
#  [45865.1274021 ]
#  [46491.11886084]
#  [47251.71473485]
#  [47946.36200345]
#  [48856.55705708]
#  [49462.83627051]]

# %%
plt.figure(figsize=(14, 7))
plt.plot(future_predictions[30:])
plt.title('Next30days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
