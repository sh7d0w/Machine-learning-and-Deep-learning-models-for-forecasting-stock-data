# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Đọc file CSV
file_path = 'VNM_Historical_Data.csv'  # Đường dẫn đến file CSV của bạn
data = pd.read_csv(file_path)

# Chuyển đổi cột 'Date' thành datetime và sắp xếp dữ liệu
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%y')
data.sort_values('Date', inplace=True)

data
# Out:
#            Date     Close      Open      High       Low     Vol.  Change %
# 0    2017-01-03  100082.0   99213.0  100319.0   99213.0   782840      0.88
# 1    2017-01-04  100240.0  100714.0  100793.0  100161.0   791240      0.16
# 2    2017-01-05  100082.0  100398.0  100398.0   99687.0   986830     -0.16
# 3    2017-01-06   99529.0  100082.0  100793.0   99529.0  1650000     -0.55
# 4    2017-01-09   99529.0  100082.0  100161.0   99529.0  1090000      0.00
# ...         ...       ...       ...       ...       ...      ...       ...
# 1736 2023-12-14   68400.0   68400.0   68900.0   68200.0  1460000      0.29
# 1737 2023-12-15   68100.0   68500.0   68600.0   68100.0  3740000     -0.44
# 1738 2023-12-18   67000.0   68100.0   68200.0   67000.0  3510000     -1.62
# 1739 2023-12-19   67000.0   67100.0   67400.0   66300.0  3060000      0.00
# 1740 2023-12-20   68100.0   67000.0   68200.0   67000.0  2600000      1.64
#
# [1741 rows x 7 columns]

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.title('Stock Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.6)
test_size = int(len(scaled_target) * 0.3)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
# Chọn 'Close' làm giá trị cần dự đoán
target = data['Close']

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(np.array(target).reshape(-1, 1)).reshape(-1)

# Chia dữ liệu thành tập train, test, và validate
train_size = int(len(scaled_target) * 0.5)
test_size = int(len(scaled_target) * 0.3)
train_data, remaining_data = scaled_target[:train_size], scaled_target[train_size:]
test_data, validate_data = train_test_split(remaining_data, test_size=test_size, shuffle=False)

# %%
def create_dataset(dataset, time_step):
    X, Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step)]
        X.append(a)
        Y.append(dataset[i + time_step])
    return np.array(X), np.array(Y)

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_validate, y_validate = create_dataset(validate_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_validate = X_validate.reshape(X_validate.shape[0], X_validate.shape[1], 1)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(100, 1)))
model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\ngomi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 25/25 [==============================] - 2s 27ms/step - loss: 0.0371 - val_loss: 0.0019
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0014
# Epoch 3/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 4/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 5/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 6/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 7/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 7.3790e-04
# Epoch 8/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 6.7413e-04
# Epoch 9/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 11/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 12/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 5.5953e-04
# Epoch 13/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 7.5270e-04
# Epoch 14/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 9.8335e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 6.3664e-04
# Epoch 17/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 18/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 8.5056e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 3.9628e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 4.7075e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 4.0465e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 5.0493e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 4.6603e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 9.3157e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 8.9829e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 7.4085e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 28/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 8.6807e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 10ms/step - loss: 8.4018e-04 - val_loss: 0.0010
# Epoch 30/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 31/100
# 25/25 [==============================] - 0s 14ms/step - loss: 9.0682e-04 - val_loss: 0.0021
# Epoch 32/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 33/100
# 25/25 [==============================] - 0s 10ms/step - loss: 9.7790e-04 - val_loss: 0.0016
# Epoch 34/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.4826e-04 - val_loss: 0.0016
# Epoch 35/100
# 25/25 [==============================] - 0s 15ms/step - loss: 7.4915e-04 - val_loss: 0.0011
# Epoch 36/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.5815e-04 - val_loss: 0.0017
# Epoch 37/100
# 25/25 [==============================] - 0s 16ms/step - loss: 8.5402e-04 - val_loss: 8.3777e-04
# Epoch 38/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 39/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.6007e-04 - val_loss: 0.0014
# Epoch 40/100
# 25/25 [==============================] - 0s 15ms/step - loss: 9.2184e-04 - val_loss: 0.0015
# Epoch 41/100
# 25/25 [==============================] - 0s 14ms/step - loss: 7.6577e-04 - val_loss: 0.0020
# Epoch 42/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 43/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.5840e-04 - val_loss: 0.0014
# Epoch 44/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.0461e-04 - val_loss: 9.5985e-04
# Epoch 45/100
# 25/25 [==============================] - 0s 15ms/step - loss: 8.2077e-04 - val_loss: 0.0013
# Epoch 46/100
# 25/25 [==============================] - 0s 14ms/step - loss: 9.4353e-04 - val_loss: 0.0017
# Epoch 47/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.1225e-04 - val_loss: 0.0013
# Epoch 48/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 49/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.0815e-04 - val_loss: 0.0012
# Epoch 50/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.7195e-04 - val_loss: 0.0015
# Epoch 51/100
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3920e-04 - val_loss: 0.0018
# Epoch 52/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.4107e-04 - val_loss: 0.0013
# Epoch 53/100
# 25/25 [==============================] - 1s 21ms/step - loss: 7.8671e-04 - val_loss: 0.0011
# Epoch 54/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.8510e-04 - val_loss: 0.0011
# Epoch 55/100
# 25/25 [==============================] - 1s 25ms/step - loss: 5.0297e-04 - val_loss: 0.0015
# Epoch 56/100
# 25/25 [==============================] - 0s 18ms/step - loss: 7.5243e-04 - val_loss: 0.0014
# Epoch 57/100
# 25/25 [==============================] - 0s 15ms/step - loss: 7.0937e-04 - val_loss: 0.0023
# Epoch 58/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.0719e-04 - val_loss: 0.0018
# Epoch 59/100
# 25/25 [==============================] - 0s 16ms/step - loss: 8.3321e-04 - val_loss: 0.0015
# Epoch 60/100
# 25/25 [==============================] - 0s 16ms/step - loss: 7.0245e-04 - val_loss: 0.0021
# Epoch 61/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.0155e-04 - val_loss: 0.0017
# Epoch 62/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.2970e-04 - val_loss: 0.0013
# Epoch 63/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.5156e-04 - val_loss: 0.0015
# Epoch 64/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7590e-04 - val_loss: 0.0011
# Epoch 65/100
# 25/25 [==============================] - 0s 18ms/step - loss: 5.3611e-04 - val_loss: 0.0015
# Epoch 66/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.8540e-04 - val_loss: 0.0012
# Epoch 67/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.8367e-04 - val_loss: 0.0012
# Epoch 68/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.1192e-04 - val_loss: 0.0019
# Epoch 69/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.3419e-04 - val_loss: 0.0021
# Epoch 70/100
# 25/25 [==============================] - 0s 19ms/step - loss: 7.9975e-04 - val_loss: 0.0026
# Epoch 71/100
# 25/25 [==============================] - 1s 25ms/step - loss: 5.4833e-04 - val_loss: 0.0019
# Epoch 72/100
# 25/25 [==============================] - 1s 24ms/step - loss: 5.7611e-04 - val_loss: 0.0013
# Epoch 73/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.7818e-04 - val_loss: 0.0021
# Epoch 74/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 75/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 76/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.6426e-04 - val_loss: 0.0022
# Epoch 77/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 78/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 79/100
# 25/25 [==============================] - 0s 17ms/step - loss: 7.6534e-04 - val_loss: 0.0021
# Epoch 80/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.6864e-04 - val_loss: 0.0023
# Epoch 81/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.1893e-04 - val_loss: 0.0025
# Epoch 82/100
# 25/25 [==============================] - 1s 22ms/step - loss: 4.1230e-04 - val_loss: 0.0018
# Epoch 83/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.1423e-04 - val_loss: 0.0016
# Epoch 84/100
# 25/25 [==============================] - 0s 19ms/step - loss: 4.4946e-04 - val_loss: 0.0018
# Epoch 85/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.5149e-04 - val_loss: 0.0019
# Epoch 86/100
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6534e-04 - val_loss: 0.0016
# Epoch 87/100
# 25/25 [==============================] - 0s 16ms/step - loss: 8.9000e-04 - val_loss: 0.0023
# Epoch 88/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 89/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.6135e-04 - val_loss: 0.0012
# Epoch 90/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.7811e-04 - val_loss: 0.0024
# Epoch 91/100
# 25/25 [==============================] - 0s 20ms/step - loss: 4.3301e-04 - val_loss: 0.0020
# Epoch 92/100
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7057e-04 - val_loss: 0.0018
# Epoch 93/100
# 25/25 [==============================] - 0s 20ms/step - loss: 4.3509e-04 - val_loss: 0.0010
# Epoch 94/100
# 25/25 [==============================] - 0s 17ms/step - loss: 9.4959e-04 - val_loss: 0.0021
# Epoch 95/100
# 25/25 [==============================] - 0s 16ms/step - loss: 9.9513e-04 - val_loss: 0.0024
# Epoch 96/100
# 25/25 [==============================] - 1s 26ms/step - loss: 5.4214e-04 - val_loss: 0.0027
# Epoch 97/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.3331e-04 - val_loss: 0.0021
# Epoch 98/100
# 25/25 [==============================] - 1s 22ms/step - loss: 5.9489e-04 - val_loss: 0.0018
# Epoch 99/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.9793e-04 - val_loss: 0.0029
# Epoch 100/100
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0023

# %%
# Dự đoán trên tập test
test_predictions = model.predict(X_test)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
test_predictions_inverse = scaler.inverse_transform(test_predictions)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_test = mean_absolute_error(y_test_inverse, test_predictions_inverse)
rmse_test = np.sqrt(mean_squared_error(y_test_inverse, test_predictions_inverse))
mape_test = np.mean(np.abs((y_test_inverse - test_predictions_inverse) / y_test_inverse)) * 100

# In kết quả
print(f'Test MAE: {mae_test}, Test RMSE: {rmse_test}, Test MAPE: {mape_test}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_test_inverse, label='Thực tế')
plt.plot(test_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Test Giá Cổ Phiếu')
plt.xlabel('Date')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 1s 8ms/step
# Test MAE: 1534.9919921874994, Test RMSE: 1880.9778408826037, Test MAPE: 1.726525292701813%

# %%
# Dự đoán trên tập validate
validate_predictions = model.predict(X_validate)

# Chuyển đổi dự đoán và giá trị thực tế về dạng ban đầu
validate_predictions_inverse = scaler.inverse_transform(validate_predictions)
y_validate_inverse = scaler.inverse_transform(y_validate.reshape(-1, 1))

# Tính các chỉ số đánh giá
mae_validate = mean_absolute_error(y_validate_inverse, validate_predictions_inverse)
rmse_validate = np.sqrt(mean_squared_error(y_validate_inverse, validate_predictions_inverse))
mape_validate = np.mean(np.abs((y_validate_inverse - validate_predictions_inverse) / y_validate_inverse)) * 100

# In kết quả
print(f'Validate MAE: {mae_validate}, Validate RMSE: {rmse_validate}, Validate MAPE: {mape_validate}%')

# Visualize kết quả
plt.figure(figsize=(10, 6))
plt.plot(y_validate_inverse, label='Thực tế')
plt.plot(validate_predictions_inverse, label='Dự đoán')
plt.title('Dự đoán Validate Giá Cổ Phiếu VNM')
plt.xlabel('Thời gian')
plt.ylabel('Giá Cổ Phiếu')
plt.legend()
plt.show()
# Out:
# 14/14 [==============================] - 0s 5ms/step
# Validate MAE: 4877.750426811164, Validate RMSE: 5531.992458099139, Validate MAPE: 6.919282461950813%

# %%
# Chuẩn bị dữ liệu đầu vào cho việc dự đoán
last_data = scaled_target[-100:]  # Lấy 100 điểm dữ liệu cuối cùng
current_batch = last_data.reshape((1, 100, 1))

# Dự đoán cho 30 ngày tiếp theo
for i in range(30):
    # Dự đoán cho ngày tiếp theo
    pred_next = model.predict(current_batch)[0]
    # Cập nhật dữ liệu đầu vào
    current_batch = np.append(current_batch[:,1:,:], [[pred_next]], axis=1)

# Chuyển đổi kết quả dự đoán về dạng ban đầu
future_predictions = scaler.inverse_transform(current_batch.reshape(-1, 1))

# In kết quả dự đoán
print(future_predictions[30:])  # In ra 30 giá trị dự đoán mới nhất
# Out:
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# [[ 67000.        ]
#  [ 68000.        ]
#  [ 67600.        ]
#  [ 68000.        ]
#  [ 70400.        ]
#  [ 70900.        ]
#  [ 70000.        ]
#  [ 71000.        ]
#  [ 70800.        ]
#  [ 71400.        ]
#  [ 70700.        ]
#  [ 69600.        ]
#  [ 68700.        ]
#  [ 68900.        ]
#  [ 70700.        ]
#  [ 70300.        ]
#  [ 70000.        ]
#  [ 69300.        ]
#  [ 69500.        ]
#  [ 69400.        ]
#  [ 68700.        ]
#  [ 68300.        ]
#  [ 68100.        ]
#  [ 68500.        ]
#  [ 68400.        ]
#  [ 67400.        ]
#  [ 68400.        ]
#  [ 68800.        ]
#  [ 68100.        ]
#  [ 68500.        ]
#  [ 68400.        ]
#  [ 69000.        ]
#  [ 70000.        ]
#  [ 69400.        ]
#  [ 68200.        ]
#  [ 68400.        ]
#  [ 68100.        ]
#  [ 67000.        ]
#  [ 67000.        ]
#  [ 68100.        ]
#  [ 76011.41810094]
#  [ 79730.38662195]
#  [ 82968.14376002]
#  [ 84806.65575632]
#  [ 86547.73611367]
#  [ 88269.36114636]
#  [ 90082.31939737]
#  [ 91496.71689994]
#  [ 93013.25443104]
#  [ 94568.46071877]
#  [ 96111.66776767]
#  [ 97721.51454165]
#  [ 99456.654901  ]
#  [101054.42748349]
#  [102587.4886683 ]
#  [104120.2500425 ]
#  [105877.15392761]
#  [107823.68803248]
#  [109209.5285731 ]
#  [110584.66451166]
#  [112275.33069048]
#  [114104.88414092]
#  [116159.32962884]
#  [118239.21132267]
#  [120353.87786278]
#  [122298.82433411]
#  [124095.57577673]
#  [125773.54088728]
#  [127499.03279564]
#  [129067.48526186]]

# %%
plt.figure(figsize=(14, 7))
plt.plot(future_predictions[30:])
plt.title('Next30days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
