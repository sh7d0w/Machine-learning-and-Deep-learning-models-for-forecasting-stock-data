# %%
 # !pip install pydlm
# Out:
# Collecting pydlm
#   Downloading pydlm-0.1.1.12-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pydlm) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pydlm) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pydlm) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pydlm) (1.16.0)
# Installing collected packages: pydlm
# Successfully installed pydlm-0.1.1.12

# %%
import math
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
from sklearn.preprocessing import RobustScaler
from keras.models import Sequential
from pydlm import dlm, trend, seasonality, dynamic
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error, mean_squared_error

# %%
data = pd.read_csv('F.csv')

# %%
data.corr().style.format("{:.5}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <ipython-input-4-0ec218d4fe38>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().style.format("{:.5}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# <style type="text/css">
# #T_18e2e_row0_col0, #T_18e2e_row0_col1, #T_18e2e_row0_col2, #T_18e2e_row0_col3, #T_18e2e_row1_col0, #T_18e2e_row1_col1, #T_18e2e_row1_col2, #T_18e2e_row1_col3, #T_18e2e_row2_col0, #T_18e2e_row2_col1, #T_18e2e_row2_col2, #T_18e2e_row2_col3, #T_18e2e_row3_col0, #T_18e2e_row3_col1, #T_18e2e_row3_col2, #T_18e2e_row3_col3, #T_18e2e_row4_col4, #T_18e2e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18e2e_row0_col4, #T_18e2e_row3_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_18e2e_row0_col5, #T_18e2e_row1_col5, #T_18e2e_row2_col5, #T_18e2e_row3_col5, #T_18e2e_row4_col5, #T_18e2e_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_18e2e_row1_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_18e2e_row2_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_18e2e_row4_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_18e2e_row4_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_18e2e_row4_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_18e2e_row4_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_18e2e_row5_col0, #T_18e2e_row5_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_18e2e_row5_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_18e2e_row5_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# </style>
# <table id="T_18e2e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18e2e_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_18e2e_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_18e2e_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_18e2e_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_18e2e_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_18e2e_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18e2e_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_18e2e_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_18e2e_row0_col1" class="data row0 col1" >0.99888</td>
#       <td id="T_18e2e_row0_col2" class="data row0 col2" >0.99868</td>
#       <td id="T_18e2e_row0_col3" class="data row0 col3" >0.99773</td>
#       <td id="T_18e2e_row0_col4" class="data row0 col4" >0.78367</td>
#       <td id="T_18e2e_row0_col5" class="data row0 col5" >-0.06557</td>
#     </tr>
#     <tr>
#       <th id="T_18e2e_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_18e2e_row1_col0" class="data row1 col0" >0.99888</td>
#       <td id="T_18e2e_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_18e2e_row1_col2" class="data row1 col2" >0.99818</td>
#       <td id="T_18e2e_row1_col3" class="data row1 col3" >0.99888</td>
#       <td id="T_18e2e_row1_col4" class="data row1 col4" >0.79274</td>
#       <td id="T_18e2e_row1_col5" class="data row1 col5" >-0.045061</td>
#     </tr>
#     <tr>
#       <th id="T_18e2e_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_18e2e_row2_col0" class="data row2 col0" >0.99868</td>
#       <td id="T_18e2e_row2_col1" class="data row2 col1" >0.99818</td>
#       <td id="T_18e2e_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_18e2e_row2_col3" class="data row2 col3" >0.99879</td>
#       <td id="T_18e2e_row2_col4" class="data row2 col4" >0.7776</td>
#       <td id="T_18e2e_row2_col5" class="data row2 col5" >-0.089566</td>
#     </tr>
#     <tr>
#       <th id="T_18e2e_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_18e2e_row3_col0" class="data row3 col0" >0.99773</td>
#       <td id="T_18e2e_row3_col1" class="data row3 col1" >0.99888</td>
#       <td id="T_18e2e_row3_col2" class="data row3 col2" >0.99879</td>
#       <td id="T_18e2e_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_18e2e_row3_col4" class="data row3 col4" >0.7864</td>
#       <td id="T_18e2e_row3_col5" class="data row3 col5" >-0.067102</td>
#     </tr>
#     <tr>
#       <th id="T_18e2e_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_18e2e_row4_col0" class="data row4 col0" >0.78367</td>
#       <td id="T_18e2e_row4_col1" class="data row4 col1" >0.79274</td>
#       <td id="T_18e2e_row4_col2" class="data row4 col2" >0.7776</td>
#       <td id="T_18e2e_row4_col3" class="data row4 col3" >0.7864</td>
#       <td id="T_18e2e_row4_col4" class="data row4 col4" >1.0</td>
#       <td id="T_18e2e_row4_col5" class="data row4 col5" >0.22079</td>
#     </tr>
#     <tr>
#       <th id="T_18e2e_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_18e2e_row5_col0" class="data row5 col0" >-0.06557</td>
#       <td id="T_18e2e_row5_col1" class="data row5 col1" >-0.045061</td>
#       <td id="T_18e2e_row5_col2" class="data row5 col2" >-0.089566</td>
#       <td id="T_18e2e_row5_col3" class="data row5 col3" >-0.067102</td>
#       <td id="T_18e2e_row5_col4" class="data row5 col4" >0.22079</td>
#       <td id="T_18e2e_row5_col5" class="data row5 col5" >1.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(data)

# %%
df = df[['Close','High']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index

# %%
train_size = int(0.6 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# %%
from pydlm import dlm, trend, autoReg, dynamic

# Assuming train_data and y_train are already defined

high_feature = []
for price in train_data['High']:
    high_feature.append([price])

# Define the DLM model
myDLM = dlm(y_train)

# Add a linear trend component with prior covariance 1.0
myDLM = myDLM + trend(1, name='lineTrend', w=1.0)

# Add an autoregressive component with a prior covariance of 1e7
myDLM = myDLM + autoReg(degree=1, data=y_train, name='ar1', w=1e7)

# Add a dynamic component with the high_feature
myDLM = myDLM + dynamic(features=high_feature, discount=1, name='High')

# Fit the DLM model
myDLM.fit()

# Print the fitted model
print(myDLM)
# Out:
# /usr/local/lib/python3.10/dist-packages/pydlm/modeler/autoReg.py:75: UserWarning: The data argument in autoReg is deprecated. Please avoid using it.
#   warn('The data argument in autoReg is deprecated. Please avoid using it.')
# Initializing models...
# Initialization finished.
# Starting forward filtering...
# Forward filtering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# <pydlm.dlm.dlm object at 0x7a13ca72feb0>

# %%
# Quá trình testing, and predict test
x_test= []
for price in test_data['High']:
  x_test.append([price])
print(np.array(x_test).shape)
y_test = np.array(test_data['Close'])
y_test_pred = myDLM.predictN(date = myDLM.n-1, N=len(x_test),featureDict={'High': x_test})
y_test_pred = y_test_pred[0]
# Out:
# (600, 1)

# %%
mae = mean_absolute_error(y_test, y_test_pred)
mape = mean_absolute_percentage_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("MAPE:", mape * 100)
print("RMSE:", rmse)
# Out:
# MAE: 1.9140007966116848
# MAPE: 26.49198617213141
# RMSE: 2.4747572061361525

# %%
#Quá trình validate, and predict val
y_val = np.array(val_data['High'])
x_val= []
for price in val_data['High']:
  x_val.append([price])
print(type(x_val))
size = test_size + val_size
y_pred_val = myDLM.predictN(featureDict={'High': x_val}, N = len(x_val))
y_pred_val = y_pred_val[0]
900017066, 9.60014529110024, 9.591199090753374, 9.58858578125013, 9.590425956255022, 9.596506785351119, 9.594211015083014, 9.59988512955646, 9.600227936443929, 9.60330451459197, 9.615174749650967, 9.618284011522984, 9.627534597275547, 9.634780419490303, 9.641973646920933, 9.64208557930801, 9.645481871122044, 9.646709961350588, 9.649587739972246, 9.671170002639505, 9.672401789415888, 9.672045402123576, 9.673463381433969, 9.671403574872667, 9.674293768721498, 9.66599945623485, 9.66181314525753, 9.670046926241014, 9.679192185217588, 9.682439329217305, 9.684136950855777, 9.691764975732818, 9.696320897236587, 9.707346271432762, 9.716196246592862, 9.72053634692566, 9.71047468027314, 9.708687802219535, 9.712334167740892, 9.716013583198169, 9.71861332807874, 9.722653707269334, 9.71645720117239, 9.728334701865641, 9.736063572445659, 9.737380396398462, 9.73840570333202, 9.736211768246442, 9.73572074029866, 9.73683753365263, 9.728632979571548, 9.746310087485345, 9.74820147855859, 9.752739703201554, 9.754371989650524, 9.755073333138998, 9.759517780463156 ...

# %%
# Thực hiện dự đoán 30 ngày tiếp theo của feature 'High' dựa trên Linear Regression
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model.fit(np.array(train_data.index).reshape(-1,1), train_data['High'])

#Quá trình testing
x_test_LR = np.array(test_data.index).reshape(-1, 1)
y_test_LR = np.array(test_data['High'])
y_pred_LR = LR_model.predict(x_test_LR)

# Quá trình Validate
x_val_LR= np.array(val_data.index).reshape(-1, 1)
y_val_LR = np.array(val_data)
y_pred_val_LR =  LR_model.predict(x_val_LR)

# Predict the prices for the next 30 days
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

feature_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
feature_next_30_days = LR_model.predict(feature_next_30_days)

print(feature_next_30_days)
# Out:
# [9.04839515 9.04643314 9.04447112 9.04250911 9.0405471  9.03858508
#  9.03662307 9.03466105 9.03269904 9.03073703 9.02877501 9.026813
#  9.02485098 9.02288897 9.02092696 9.01896494 9.01700293 9.01504091
#  9.0130789  9.01111689 9.00915487 9.00719286 9.00523084 9.00326883
#  9.00130682 8.9993448  8.99738279 8.99542077 8.99345876 8.99149675]

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

x = []
for price in feature_next_30_days:
  x.append([price])
print(type(x))
num_dims = np.ndim(x)
print(num_dims)
y_next_30_days = myDLM.predictN(featureDict={'High': x}, N = 30)
y_next_30_days = y_next_30_days[0]
print(y_next_30_days)
# Out:
# <class 'list'>
# 2
# [8.795905719161098, 8.800056583876467, 8.804296253073847, 8.808531428316732, 8.812766830976368, 8.817002222127572, 8.821237613861161, 8.825473005565277, 8.829708397270885, 8.83394378897642, 8.838179180681955, 8.842414572387492, 8.846649964093029, 8.850885355798564, 8.8551207475041, 8.859356139209638, 8.863591530915173, 8.86782692262071, 8.872062314326245, 8.876297706031782, 8.880533097737318, 8.884768489442854, 8.88900388114839, 8.893239272853927, 8.897474664559462, 8.901710056265, 8.905945447970534, 8.910180839676071, 8.914416231381608, 8.918651623087143]

# %%
plt.plot(train_data.index, train_data['Close'])
plt.plot(test_data.index, test_data['Close'])
plt.plot(val_data.index,val_data['Close'])
plt.plot(val_data.index,y_pred_val)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Validate','ValidatePred','Predict30Days'])
plt.show()
