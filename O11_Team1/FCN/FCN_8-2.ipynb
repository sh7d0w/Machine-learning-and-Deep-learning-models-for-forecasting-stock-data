# %% [markdown]
# # Import thư viện

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ABC

# %% [markdown]
# # Đọc và tiền xử lí dữ liệu

# %%
# Chuẩn bị dữ liệu

path ="/content/drive/MyDrive/Colab Notebooks/Data Analysis in Business 1/DATASET/ACB Historical Data.csv"
data = pd.read_csv(path, index_col='Date', parse_dates=True)

# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)

# Áp dụng hàm chuyển đổi cho cột "Vol."
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
data["Change %"] = data["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'] = data['Price'].apply(convert_str_to_number)
data['Open'] = data['Open'].apply(convert_str_to_number)
data['High'] = data['High'].apply(convert_str_to_number)
data['Low'] = data['Low'].apply(convert_str_to_number)

data = data.reset_index(drop=True)

data
# Out:
#         Price     Open     High      Low      Vol.  Change %
# 0     10537.7  10477.8  10567.6  10417.9   7360000    0.0086
# 1     10926.9  10537.7  10956.8  10537.7   9450000    0.0369
# 2     10477.8  10956.8  10956.8  10477.8   8189999   -0.0411
# 3     10447.9  10447.9  10627.5  10328.1   9810000   -0.0029
# 4     10837.1  10447.9  10837.1  10447.9   8300000    0.0373
# ...       ...      ...      ...      ...       ...       ...
# 1506  22800.0  22700.0  22800.0  22650.0   6390000    0.0022
# 1507  23050.0  22800.0  23100.0  22800.0  11470000    0.0110
# 1508  23200.0  23050.0  23250.0  23050.0   8860000    0.0065
# 1509  23250.0  23200.0  23250.0  23050.0   7080000    0.0022
# 1510  23200.0  23200.0  23300.0  23200.0   4510000   -0.0022
#
# [1511 rows x 6 columns]

# %% [markdown]
# # Phân chia dữ liệu

# %%
price = data['Price'].values
price = price.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# Chia dữ liệu thành train test validate
train_size = int(len(price_scaled) * 0.8)
test_size = int(len(price_scaled) * 0.2)
#val_size = len(price_scaled) - train_size - test_size

train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]
#val_data = price_scaled[train_size+test_size:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Xây dựng mô hình và train

# %%
# Xây dựng mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 19/19 [==============================] - 4s 97ms/step - loss: 0.0534 - val_loss: 0.0055
# Epoch 2/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 3/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 4/100
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 5/100
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 6/100
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 7/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 8/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 9/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 10/100
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 11/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 12/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 13/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 14/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 15/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 16/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 17/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 18/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 19/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 20/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 21/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 22/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 23/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 24/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 25/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 26/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 27/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 28/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 29/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 30/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 31/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 32/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 33/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 34/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 35/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 36/100
# 19/19 [==============================] - 1s 49ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 37/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 38/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 39/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 40/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 41/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 42/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 43/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 44/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 45/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 46/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 47/100
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 48/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 49/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 50/100
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 51/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 52/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 53/100
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 54/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 55/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 56/100
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 57/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 58/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 59/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 60/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 61/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 62/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 63/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 64/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 65/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 66/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 67/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 68/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 69/100
# 19/19 [==============================] - 1s 64ms/step - loss: 9.5944e-04 - val_loss: 0.0012
# Epoch 70/100
# 19/19 [==============================] - 1s 63ms/step - loss: 9.4967e-04 - val_loss: 0.0012
# Epoch 71/100
# 19/19 [==============================] - 1s 69ms/step - loss: 9.7663e-04 - val_loss: 0.0012
# Epoch 72/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0011 - val_loss: 0.0037
# Epoch 73/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 74/100
# 19/19 [==============================] - 1s 47ms/step - loss: 9.8483e-04 - val_loss: 0.0015
# Epoch 75/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 76/100
# 19/19 [==============================] - 1s 37ms/step - loss: 9.9741e-04 - val_loss: 0.0016
# Epoch 77/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 78/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 79/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 80/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 81/100
# 19/19 [==============================] - 1s 38ms/step - loss: 9.9171e-04 - val_loss: 0.0012
# Epoch 82/100
# 19/19 [==============================] - 1s 38ms/step - loss: 9.3989e-04 - val_loss: 0.0013
# Epoch 83/100
# 19/19 [==============================] - 1s 37ms/step - loss: 9.5241e-04 - val_loss: 0.0012
# Epoch 84/100
# 19/19 [==============================] - 1s 37ms/step - loss: 8.4844e-04 - val_loss: 0.0017
# Epoch 85/100
# 19/19 [==============================] - 1s 38ms/step - loss: 9.4862e-04 - val_loss: 0.0014
# Epoch 86/100
# 19/19 [==============================] - 1s 37ms/step - loss: 9.9934e-04 - val_loss: 0.0016
# Epoch 87/100
# 19/19 [==============================] - 1s 37ms/step - loss: 8.7369e-04 - val_loss: 0.0013
# Epoch 88/100
# 19/19 [==============================] - 1s 51ms/step - loss: 9.0041e-04 - val_loss: 0.0013
# Epoch 89/100
# 19/19 [==============================] - 1s 62ms/step - loss: 8.6448e-04 - val_loss: 0.0014
# Epoch 90/100
# 19/19 [==============================] - 1s 62ms/step - loss: 9.3828e-04 - val_loss: 0.0014
# Epoch 91/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 92/100
# 19/19 [==============================] - 1s 65ms/step - loss: 8.7231e-04 - val_loss: 0.0021
# Epoch 93/100
# 19/19 [==============================] - 1s 61ms/step - loss: 9.2953e-04 - val_loss: 0.0012
# Epoch 94/100
# 19/19 [==============================] - 1s 36ms/step - loss: 9.3636e-04 - val_loss: 0.0021
# Epoch 95/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 96/100
# 19/19 [==============================] - 1s 38ms/step - loss: 9.1430e-04 - val_loss: 0.0013
# Epoch 97/100
# 19/19 [==============================] - 1s 36ms/step - loss: 8.0259e-04 - val_loss: 0.0012
# Epoch 98/100
# 19/19 [==============================] - 1s 38ms/step - loss: 8.9423e-04 - val_loss: 0.0022
# Epoch 99/100
# 19/19 [==============================] - 1s 38ms/step - loss: 8.9826e-04 - val_loss: 0.0014
# Epoch 100/100
# 19/19 [==============================] - 1s 37ms/step - loss: 8.3870e-04 - val_loss: 0.0013

# %% [markdown]
# # Dự báo trên tập test / validate và đánh giá mô hình

# %%
# Dự báo
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 9/9 [==============================] - 0s 6ms/step

# %%
# Hàm tính MDA
def calculate_mda(y_true, y_pred):
    y_true_diff = np.diff(y_true)
    y_pred_diff = np.diff(y_pred)
    correct_direction = np.sign(y_true_diff) == np.sign(y_pred_diff)
    return np.mean(correct_direction) * 100

# Tính toán RMSE, MAE và MAPE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mda = calculate_mda(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MDA trên tập test là:', test_score_mda, '%')
# Out:
# RMSE trên tập test là: 785.1130878535981
# MAPE trên tập test là: 2.6669147020765607 %
# MDA trên tập test là: 39.705882352941174 %

# %% [markdown]
# # Dự báo 30 ngày tiếp theo

# %%
# Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# [[23466.928]
#  [23663.826]
#  [23894.777]
#  [24100.656]
#  [24270.586]
#  [24429.709]
#  [24550.701]
#  [24626.617]
#  [24688.719]
#  [24750.383]
#  [24815.182]
#  [24901.85 ]
#  [25014.28 ]
#  [25171.375]
#  [25361.123]
#  [25516.852]
#  [25612.488]
#  [25658.223]
#  [25673.197]
#  [25681.754]
#  [25732.477]
#  [25811.46 ]
#  [25864.582]
#  [25858.812]
#  [25804.52 ]
#  [25732.088]
#  [25662.377]
#  [25605.594]
#  [25566.85 ]
#  [25553.176]]

# %% [markdown]
# # Chuyển các chuỗi np thành dataframe để vẽ đồ thị

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]
#val_data_df = data[train_size+test_size:][['Price']]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Vẽ đồ thị các giá trị từ train tới validate và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %% [markdown]
# # PVS

# %% [markdown]
# # Đọc và tiền xử lí dữ liệu

# %%
# Chuẩn bị dữ liệu

path ="/content/drive/MyDrive/Colab Notebooks/Data Analysis in Business 1/DATASET/PVS Historical Data.csv"
data = pd.read_csv(path, index_col='Date', parse_dates=True)

# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)

# Áp dụng hàm chuyển đổi cho cột "Vol."
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
data["Change %"] = data["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'] = data['Price'].apply(convert_str_to_number)
data['Open'] = data['Open'].apply(convert_str_to_number)
data['High'] = data['High'].apply(convert_str_to_number)
data['Low'] = data['Low'].apply(convert_str_to_number)

data = data.reset_index(drop=True)

data
# Out:
#         Price     Open     High      Low      Vol.  Change %
# 0     17292.0  16746.0  17474.0  16655.0  12030000    0.0440
# 1     17838.0  17383.0  17838.0  17383.0   6600000    0.0316
# 2     17292.0  18020.0  18020.0  17292.0   6460000   -0.0306
# 3     17565.0  17201.0  17656.0  16837.0   8730000    0.0158
# 4     17110.0  17383.0  17474.0  17019.0   6100000   -0.0259
# ...       ...      ...      ...      ...       ...       ...
# 1511  37400.0  37500.0  38000.0  37400.0   1840000   -0.0027
# 1512  37900.0  37600.0  37900.0  37100.0   2540000    0.0134
# 1513  38400.0  37900.0  38600.0  37900.0   3040000    0.0132
# 1514  38200.0  37400.0  38700.0  37400.0   1440000   -0.0052
# 1515  38300.0  38000.0  38500.0  38000.0   2340000    0.0026
#
# [1516 rows x 6 columns]

# %% [markdown]
# # Phân chia dữ liệu

# %%
price = data['Price'].values
price = price.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# Chia dữ liệu thành train test validate
train_size = int(len(price_scaled) * 0.8)
test_size = int(len(price_scaled) * 0.2)

train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Xây dựng mô hình và train

# %%
# Xây dựng mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 82ms/step - loss: 0.0344 - val_loss: 0.0270
# Epoch 2/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 3/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 4/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 5/100
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0058 - val_loss: 0.0088
# Epoch 6/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0057 - val_loss: 0.0071
# Epoch 7/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 8/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 9/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0057 - val_loss: 0.0123
# Epoch 10/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 11/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0055 - val_loss: 0.0076
# Epoch 12/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0054 - val_loss: 0.0074
# Epoch 13/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0056 - val_loss: 0.0069
# Epoch 14/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0053 - val_loss: 0.0101
# Epoch 15/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0052 - val_loss: 0.0085
# Epoch 16/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0052 - val_loss: 0.0100
# Epoch 17/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0050 - val_loss: 0.0041
# Epoch 18/100
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0047 - val_loss: 0.0121
# Epoch 19/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 20/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0041 - val_loss: 0.0051
# Epoch 21/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 22/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 23/100
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 24/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 25/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 26/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 27/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0025 - val_loss: 0.0073
# Epoch 28/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 29/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0025 - val_loss: 0.0050
# Epoch 30/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 31/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 32/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0023 - val_loss: 0.0050
# Epoch 33/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 34/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 35/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0020 - val_loss: 0.0056
# Epoch 36/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 37/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 38/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0026 - val_loss: 0.0086
# Epoch 39/100
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0024 - val_loss: 0.0146
# Epoch 40/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 41/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 42/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0022 - val_loss: 0.0075
# Epoch 43/100
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0021 - val_loss: 0.0051
# Epoch 44/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0022 - val_loss: 0.0073
# Epoch 45/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 46/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 47/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 48/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 49/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 50/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 51/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 52/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 53/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 54/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 55/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 56/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 57/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 58/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0021 - val_loss: 0.0059
# Epoch 59/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 60/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 61/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 62/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 63/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 64/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 65/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 66/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 67/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 68/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0020 - val_loss: 0.0047
# Epoch 69/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 70/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 71/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 72/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 73/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 74/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 75/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 76/100
# 19/19 [==============================] - 1s 50ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 77/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 78/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 79/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 80/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 81/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 82/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 83/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0016 - val_loss: 0.0051
# Epoch 84/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 85/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 86/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 87/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 88/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 89/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 90/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 91/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 92/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 93/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 94/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 95/100
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 96/100
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 97/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 98/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 99/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 100/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0015 - val_loss: 0.0018

# %% [markdown]
# # Dự báo trên tập test / validate và đánh giá mô hình

# %%
# Dự báo
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 9/9 [==============================] - 0s 6ms/step

# %%
# Hàm tính MDA
def calculate_mda(y_true, y_pred):
    y_true_diff = np.diff(y_true)
    y_pred_diff = np.diff(y_pred)
    correct_direction = np.sign(y_true_diff) == np.sign(y_pred_diff)
    return np.mean(correct_direction) * 100

# Tính toán RMSE, MAE và MAPE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mda = calculate_mda(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MDA trên tập test là:', test_score_mda, '%')
# Out:
# RMSE trên tập test là: 1347.04633562707
# MAPE trên tập test là: 3.446149495550563 %
# MDA trên tập test là: 42.124542124542124 %

# %% [markdown]
# # Dự báo 30 ngày tiếp theo

# %%
# Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# [[38249.434]
#  [38298.63 ]
#  [38351.203]
#  [38274.746]
#  [38160.125]
#  [38077.246]
#  [37929.38 ]
#  [37749.336]
#  [37572.516]
#  [37458.06 ]
#  [37418.543]
#  [37253.82 ]
#  [37094.105]
#  [37125.824]
#  [37260.86 ]
#  [37312.37 ]
#  [37384.73 ]
#  [37380.57 ]
#  [37265.734]
#  [37163.117]
#  [37044.008]
#  [36890.457]
#  [36744.35 ]
#  [36596.07 ]
#  [36442.016]
#  [36298.938]
#  [36156.797]
#  [36018.766]
#  [35897.1  ]
#  [35789.05 ]]

# %% [markdown]
# # Chuyển các chuỗi np thành dataframe để vẽ đồ thị

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Vẽ đồ thị các giá trị từ train tới validate và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()

# %% [markdown]
# # VNM

# %% [markdown]
# # Đọc và tiền xử lí dữ liệu

# %%
# Chuẩn bị dữ liệu

path ="/content/drive/MyDrive/Colab Notebooks/Data Analysis in Business 1/DATASET/VNM Historical Data.csv"
data = pd.read_csv(path, index_col='Date', parse_dates=True)

# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)

# Áp dụng hàm chuyển đổi cho cột "Vol."
data["Vol."] = data["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
data["Change %"] = data["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
data['Price'] = data['Price'].apply(convert_str_to_number)
data['Open'] = data['Open'].apply(convert_str_to_number)
data['High'] = data['High'].apply(convert_str_to_number)
data['Low'] = data['Low'].apply(convert_str_to_number)

data = data.reset_index(drop=True)

data
# Out:
#          Price      Open      High       Low     Vol.  Change %
# 0     159039.0  151736.0  159039.0  151736.0  1500000    0.0498
# 1     164719.0  159039.0  166423.0  159039.0  1700000    0.0357
# 2     161473.0  164719.0  166342.0  160662.0   852080   -0.0197
# 3     158227.0  158227.0  159850.0  151898.0  1140000   -0.0201
# 4     150924.0  158227.0  160580.0  150924.0  1430000   -0.0462
# ...        ...       ...       ...       ...      ...       ...
# 1509   67000.0   68100.0   68200.0   67000.0  3510000   -0.0162
# 1510   67000.0   67100.0   67400.0   66300.0  3060000    0.0000
# 1511   68100.0   67000.0   68200.0   67000.0  2600000    0.0164
# 1512   67800.0   67900.0   68300.0   67800.0  2590000   -0.0044
# 1513   67600.0   67800.0   68100.0   67500.0  2150000   -0.0029
#
# [1514 rows x 6 columns]

# %% [markdown]
# # Phân chia dữ liệu

# %%
price = data['Price'].values
price = price.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# Chia dữ liệu thành train test validate
train_size = int(len(price_scaled) * 0.8)
test_size = int(len(price_scaled) * 0.2)

train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 30
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Xây dựng mô hình và train

# %%
# Xây dựng mô hình
model = Sequential()

# Add convolutional layers
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(look_back, 1)))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=1, kernel_size=3, activation='relu'))

# Add global average pooling layer
model.add(GlobalAveragePooling1D())

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 19/19 [==============================] - 2s 49ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 2/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 3/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 4/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 5/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 6/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 7/100
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 8/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 9/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 10/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 11/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 12/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 13/100
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 14/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 15/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 16/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 17/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 18/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 19/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 20/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 21/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 22/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 23/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 24/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 25/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 26/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 27/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 28/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 29/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 30/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 31/100
# 19/19 [==============================] - 1s 68ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 32/100
# 19/19 [==============================] - 1s 49ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 33/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 34/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 35/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 36/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 37/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 38/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 39/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 40/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 41/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 42/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 43/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 44/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 45/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 46/100
# 19/19 [==============================] - 1s 53ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 47/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 48/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 49/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 50/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 51/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 52/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 53/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 54/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 55/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 56/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 57/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 58/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 59/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 60/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 61/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 62/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 63/100
# 19/19 [==============================] - 2s 85ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 64/100
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 65/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 66/100
# 19/19 [==============================] - 2s 123ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 67/100
# 19/19 [==============================] - 2s 101ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 68/100
# 19/19 [==============================] - 2s 84ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 69/100
# 19/19 [==============================] - 2s 97ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 70/100
# 19/19 [==============================] - 2s 85ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 71/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 72/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 73/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 74/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 75/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 76/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 77/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 78/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 79/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 80/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 81/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 82/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 83/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 84/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 85/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 86/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 87/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 88/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 89/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 90/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 91/100
# 19/19 [==============================] - 1s 70ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 92/100
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 93/100
# 19/19 [==============================] - 2s 125ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 94/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 95/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 96/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 97/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 98/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 99/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.1454 - val_loss: 0.0129
# Epoch 100/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.1454 - val_loss: 0.0129

# %% [markdown]
# # Dự báo trên tập test / validate và đánh giá mô hình

# %%
# Dự báo
test_predict = model.predict(X_test)

test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 9/9 [==============================] - 0s 7ms/step

# %%
# Hàm tính MDA
def calculate_mda(y_true, y_pred):
    y_true_diff = np.diff(y_true)
    y_pred_diff = np.diff(y_pred)
    correct_direction = np.sign(y_true_diff) == np.sign(y_pred_diff)
    return np.mean(correct_direction) * 100

# Tính toán RMSE, MAE và MAPE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mda = calculate_mda(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MDA trên tập test là:', test_score_mda, '%')
# Out:
# RMSE trên tập test là: 13000.771044441286
# MAPE trên tập test là: 16.402317221886186 %
# MDA trên tập test là: 6.25 %

# %% [markdown]
# # Dự báo 30 ngày tiếp theo

# %%
# Dự báo giá trị 30 ngày trong tương lai
last_30_days = price_scaled[-30:]
next_30_days = []
for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat)
    last_30_days = np.append(last_30_days, y_hat, axis=0)

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

print(next_30_days)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# [[61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]
#  [61260.1]]

# %% [markdown]
# # Chuyển các chuỗi np thành dataframe để vẽ đồ thị

# %%
test_predict_df = pd.DataFrame(test_predict)
test_predict_index = range(len(train_data)+look_back, len(train_data)+look_back+len(test_predict))
test_predict_df.index = test_predict_index

next_30_days_df = pd.DataFrame(next_30_days)
next_30_index = range(len(data), len(data)+len(next_30_days))
next_30_days_df.index = next_30_index

train_data_df = data[:train_size][['Price']]
test_data_df = data[train_size:train_size + test_size][['Price']]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Vẽ đồ thị các giá trị từ train tới validate và dự đoán 30 ngày sau
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next 30 days')
plt.legend()
plt.show()
